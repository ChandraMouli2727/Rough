# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.0 MB 4.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.0 MB 5.7 MB/s eta 0:00:02
#    ------------------ --------------------- 3.7/8.0 MB 6.3 MB/s eta 0:00:01
#    -------------------------- ------------- 5.2/8.0 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 6.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.8/36.5 MB 8.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.7/36.5 MB 9.3 MB/s eta 0:00:04
#    ------ --------------------------------- 6.0/36.5 MB 9.4 MB/s eta 0:00:04
#    -------- ------------------------------- 7.6/36.5 MB 8.8 MB/s eta 0:00:04
# ...

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\ML_CSV\\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area(sq ft)')
plt.ylabel('price(us$)')
plt.scatter(df.area,df.price, color ='red',marker='+')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Chandra Mouli\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df['price']) #2D Array
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\Chandra Mouli\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.predict(pd.DataFrame({'area': [3300]}))
# Out:
# array([628715.75342466])

# %%
y = mx+b # m is slope(Gradient),b is Y Intercept

# %%
reg.coef_ #it is m
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# y = m*x + b slope*area + intercept
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
reg.predict([[5000]])
# Out:
# C:\Users\Chandra Mouli\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
df1 = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\ML_CSV\\areas.csv")
df1
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = reg.predict(df1)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df1['prices'] = p
df1
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
df1.to_csv("predictions_csv",index = False)

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\ML_CSV\\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg = linear_model.LinearRegression() #fit_intercept = False
reg.fit(df[['area']],df['price']) #2D Array
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('area(sq ft)')
plt.ylabel('price(us$)')
plt.scatter(df.area,df.price, color ='red',marker='+')
plt.plot(df.area,reg.predict(df[['area']]),color ='blue')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Chandra Mouli\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#Example
df2 = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\ML_CSV\\canada_per_capita_income.csv")
df2.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df2.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='str')

# %%
reg = linear_model.LinearRegression()
reg.fit(df2[['year']],df2['per capita income (US$)']) #2D Array
# Out:
# LinearRegression()

# %%
reg.predict([[2026]])
# Out:
# C:\Users\Chandra Mouli\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([46259.48454575])

# %%
reg.predict(pd.DataFrame({'year': [2020]}))
# Out:
# array([41288.69409442])

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df2.year,df2['per capita income (US$)'], color ='red',marker='+')
plt.plot(df2['year'],reg.predict(df2[['year']]),color ='blue')
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\Chandra Mouli\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
reg.coef_
# Out:
# array([828.46507522])

# %%
reg.intercept_
# Out:
# np.float64(-1632210.7578554575)
