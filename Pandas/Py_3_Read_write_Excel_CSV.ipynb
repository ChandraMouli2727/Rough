# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv")
df
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
# 5                       TATA            5.6         -1       n.a.
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani
# 5     ratan tata

# %%
#DataSource is Header use skiprows to hide go doc for another funcs/explanation
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",skiprows=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",header = 1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",header = 1,names = ["Stock Symbol","eps","revenue","price","people"])
df # Changing column names
# Out:
#   Stock Symbol            eps  revenue price         people
# 0        GOOGL          27.82       87   845     larry page
# 1          WMT           4.61      484    65           n.a.
# 2         MSFT             -1       85    64     bill gates
# 3         RIL   not available       50  1023  mukesh ambani
# 4         TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",header = 1,nrows = 2)
df # Reading only nrows if u have million records
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",header = 1,na_values = { 
          'eps':['not available'],
          'revenue':[-1],
           'people' : ['not available','n.a.'],
           'price' : ['n.a.']
})
df # Converting not available to NaN using obj
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\Desktop\\Ai_Eng\\CSV_Files\\stock_data.csv",header = 1,na_values = ['not available','n.a.',-1])
df # converting na values using list
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df["pe"] = df["price"]/df["eps"]
df
# Out:
#   tickers    eps  revenue   price         people         pe
# 0   GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1     WMT   4.61    484.0    65.0            NaN  14.099783
# 2    MSFT    NaN     85.0    64.0     bill gates        NaN
# 3    RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4    TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df.to_csv("pe.csv")

# %%
df = pd.read_csv("C:\\Users\\Chandra Mouli\\PycharmProjects1\\Rough\\Pandas\\pe.csv")
df
# Out:
#    Unnamed: 0 tickers    eps  revenue   price         people         pe
# 0           0   GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1           1     WMT   4.61    484.0    65.0            NaN  14.099783
# 2           2    MSFT    NaN     85.0    64.0     bill gates        NaN
# 3           3    RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4           4    TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tickers', 'eps', 'revenue', 'price', 'people', 'pe'], dtype='str')

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
df.to_csv("pe1.csv",index=False,header=False)

# %%
df = pd.read_csv("pe1.csv",header=0)
#df = df.drop(columns=df.columns[df.columns.str.contains('^Unnamed')])
df
# Out:
#   GOOGL  27.82   87.0   845.0     larry page  30.373831775700936
# 0   WMT   4.61  484.0    65.0            NaN           14.099783
# 1  MSFT    NaN   85.0    64.0     bill gates                 NaN
# 2  RIL     NaN   50.0  1023.0  mukesh ambani                 NaN
# 3  TATA   5.60    NaN     NaN     ratan tata                 NaN
